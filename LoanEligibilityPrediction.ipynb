# %% [markdown]
# <center>
#
# #  Loan Eligibility Prediction.
#
# </center>

# %% [markdown]
# * **Name : Siyabinga Mnyango**
# * **Surname : Mlambo**

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200>  Objectives of Notebook:</font></h2>
#
#  **This notebook aims to:**
# *   Analyze customer data provided in data set (EDA)
# *   Build various ML models that can predict loan approval
#
# <h2 align="left"><font color=#ff6200>  The machine learning models used in this project are:</font></h2>
#
# 1. Logistic Regression
# 2. Decision Tree
# 3. Support Vector Machine (SVM)
# 4. Random Forest
# 5. K-Nearest Neighbour (KNN)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> About Dataset :</font></h2>
#
# - **About this Loan dataset:**
# I collected the dataset over kaggle.com:https://www.kaggle.com/datasets/burak3ergun/loan-data-set/data.
# Which they took data set  from : https://datahack.analyticsvidhya.com/contest/practice-problem-loan-prediction-iii/
#
#
# - **Problem:**
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have given a problem to identify the customers segments, those are eligible for loan amount so that they can specifically target these customers. Here they have provided a partial data set.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200>   Data Set Description:</font></h2>
#
# There are **13 variables** in this data set:
# *   **8 categorical** variables.
# *   **5 continuous** variables.
#
#
# <h2 align="left"><font color=#ff6200>  Structure of the data set:</font></h2>
#
#
# <table style="width:100%">
# <thead>
# <tr>
# <th style="text-align:center; font-weight: bold; font-size:14px">Variable Name</th>
# <th style="text-align:center; font-weight: bold; font-size:14px">Description</th>
# <th style="text-align:center; font-weight: bold; font-size:14px">Sample Data</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><b>Loan_ID</b></td>
# <td>Loan reference number <br> (unique ID)</td>
# <td>LP001002; LP001003; ...</td>
# </tr>
# <tr>
# <td><b>Gender</b></td>
# <td>Applicant gender <br> (Male or Female)</td>
# <td>Male; Female</td>
# </tr>
# <tr>
# <td><b>Married</b></td>
# <td>Applicant marital status <br> (Married or not married)</td>
# <td>Married; Not Married</td>
# </tr>
# <tr>
# <td><b>Dependents</b></td>
# <td>Number of family members</td>
# <td>0; 1; 2; 3+</td>
# </tr>
# <tr>
# <td><b>Education</b></td>
# <td>Applicant education/qualification <br> (graduate or not graduate)</td>
# <td>Graduate; Under Graduate</td>
# </tr>
# <tr>
# <td><b>Self_Employed</b></td>
# <td>Applicant employment status <br> (yes for self-employed, no for employed/others)</td>
# <td>Yes; No</td>
# </tr>
# <tr>
# <td><b>ApplicantIncome</b></td>
# <td>Applicant's monthly salary/income</td>
# <td>5849; 4583; ...</td>
# </tr>
# <tr>
# <td><b>CoapplicantIncome</b></td>
# <td>Additional applicant's monthly salary/income</td>
# <td>1508; 2358; ...</td>
# </tr>
# <tr>
# <td><b>LoanAmount</b></td>
# <td>Loan amount</td>
# <td>128; 66; ...</td>
# </tr>
# <tr>
# <td><b>Loan_Amount_Term</b></td>
# <td>The loan's repayment period (in days)</td>
# <td>360; 120; ...</td>
# </tr>
# <tr>
# <td><b>Credit_History</b></td>
# <td>Records of previous credit history <br> (0: bad credit history, 1: good credit history)</td>
# <td>0; 1</td>
# </tr>
# <tr>
# <td><b>Property_Area</b></td>
# <td>The location of property <br> (Rural/Semiurban/Urban)</td>
# <td>Rural; Semiurban; Urban</td>
# </tr>
# <tr>
# <td><b>Loan_Status</b></td>
# <td>Status of loan <br> (Y: accepted, N: not accepted)</td>
# <td>Y; N</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">1.| Setup and Initialization</p>

# %% [markdown]
# # <b><span style='color:#fcc36d'>1.1 |</span><span style='color:#ff6200'> Installing Necessary Packages</span></b>

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install polars
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install skimpy
# Out:
# ...
#   Using cached numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached numpy-2.2.4-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\mrfac\anaconda\Lib\site-packages\~6mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\mrfac\anaconda\Lib\site-packages\~6mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.4 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# ...

# %%
pip install pybind11>=2.12 matplotlib seaborn scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# skimpy 0.0.18 requires numpy>=2.0.2, but you have numpy 1.26.4 which is incompatible.
# streamlit 1.37.1 requires rich<14,>=10.14.0, but you have rich 14.0.0 which is incompatible.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shap joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # <b><span style='color:#fcc36d'>1.2 |</span><span style='color:#ff6200'> Importing Necessary Libraries</span></b>

# %%
import numpy as np
import pandas as pd
import warnings
import os
import scipy
warnings.filterwarnings("ignore")
import polars as pl
from skimpy import skim

from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import io
import missingno as mso
from sklearn.inspection import permutation_importance
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, auc
from joblib import dump
from joblib import load
import shap
import joblib

# %% [markdown]
# # <b><span style='color:#fcc36d'>1.3 |</span><span style='color:#ff6200'> Loading the Dataset</span></b>

# %%
loan = pd.read_csv("loan_data_set.csv")

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">2. | Initial Data Analysis</p>

# %% [markdown]
# # <b><span style='color:#fcc36d'>2.1 |</span><span style='color:#ff6200'> Dataset Overview</span></b>

# %%
print("\nFirst five rows:")
loan.head()
# Out:
# First five rows:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Display shape of the DataFrame
shape_table = [["Attribute", "Value"],
             ["Number of Rows", loan.shape[0]],
            ["Number of Columns", loan.shape[1]]]
print(tabulate(shape_table, headers="firstrow", tablefmt="grid"))
# Out:
# +-------------------+---------+
# | Attribute         |   Value |
# +===================+=========+
# | Number of Rows    |     614 |
# +-------------------+---------+
# | Number of Columns |      13 |
# +-------------------+---------+

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **There are 13 columns that are readable and 614 observations in the Loan data set**.

# %%
# Check the data types and non-null counts, Generating Basic Information of the data.
print("Basic Information of this dataset:")
loan.info()
# Out:
# Basic Information of this dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **There are 614 unique ID in the dataset.**

# %%
skim(loan)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 614    │ │ string      │ 8     │                                                          │
# │ │ Number of columns │ 13     │ │ float64     │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 1     │                                                          │
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Some columns have missing values (LoanAmount, Credit_History, Self_Employed) I will need to fill or drop them before training your model.**
# * **ApplicantIncome, LoanAmount, and CoapplicantIncome have wide ranges	I will do Square Root Transformation to reduce skew.**
# * **Credit_History likely plays a strong role in loan approval.**
# * **Loan_ID is not useful for prediction therofore, I will drop this column.**
# * **Target variable Loan_Status is well balanced this is good for training more reliable.**

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">3. | Data Exploration</p>

# %% [markdown]
# # <b><span style='color:#fcc36d'>3.1 |</span><span style='color:#ff6200'> Categorical Summary Observations</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.1 Gender:</font></h2>

# %%
# Display value counts (including NaNs)
loan['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      489
# Female    112
# NaN        13
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Gender", data=loan, palette="hls")
plt.title("Gender Distribution", fontsize=14)
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - The `Gender` column contains two categories: **Male** and **Female**.
# - There are a few **missing values** (13 out of 614).
# - Most applicants are **Male**.
# - The count plot above shows a clear gender imbalance.
# - I will handle the missing values by replacing them with the **mode** (most common value), which is "Male".

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.2 Married:</font></h2>

# %%
loan['Married'].value_counts(dropna=False)
# Out:
# Married
# Yes    398
# No     213
# NaN      3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Married", data=loan, palette="Set2")
plt.title("Marital Status Distribution")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - Most applicants are **Married**.
# - A few missing values (~3).
# - I will fill missing values using the mode: "Yes".

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.3 Education:</font></h2>

# %%
loan['Education'].value_counts(dropna=False)
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Education", data=loan, palette="autumn")
plt.title("Education Level")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - Most applicants are **Graduates**.
# - No missing values here — great!
# - No action needed for this column.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.4 Property Area:</font></h2>

# %%
loan['Property_Area'].value_counts(dropna=False)
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Property_Area", data=loan, palette="pastel")
plt.title("Property Area Type")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - Property types are well-balanced: Urban, Semiurban, and Rural.
# - No missing values.
# - No cleaning needed here.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.5 Self Employed:</font></h2>

# %%
loan['Self_Employed'].value_counts(dropna=False)
# Out:
# Self_Employed
# No     500
# Yes     82
# NaN     32
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Self_Employed", data=loan, palette="Blues")
plt.title("Self Employment Status")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - Majority are **not self-employed**.
# - Around 32 values are missing.
# - Fill missing with "No" (most frequent).

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.6 Dependents:</font></h2>

# %%
loan['Dependents'].value_counts(dropna=False)
# Out:
# Dependents
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Dependents", data=loan, palette="coolwarm")
plt.title("Number of Dependents")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - Most applicants have 0 dependents.
# - A few missing values (~15).
# - I will fill the missing values with the mode: "0".

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.1.7 Loan Status:</font></h2>

# %%
loan['Loan_Status'].value_counts(dropna=False)
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Loan_Status", data=loan, palette="Set3")
plt.title("Loan Approval Status")
plt.xlabel("Loan Status", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - This is the **target variable** — what we want to predict.
# - It contains two values:
#   - `Y` = Loan Approved
#   - `N` = Loan Not Approved
# - The dataset is **slightly imbalanced** (more approved than not).
# - No missing values are present in this column
# - I will convert this column to numeric later (`Y` = 1, `N` = 0) for modeling.

# %% [markdown]
# # <b><span style='color:#fcc36d'>3.2 |</span><span style='color:#ff6200'> Numerical Summary Observations</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 3.2.1  Summary of the numerical columns:</font></h2>

# %%
# Display basic statistics for both numeric columns
print("\nBasic statistics for both numeric :")
stats = loan.describe().T
print(tabulate(stats, headers='keys', tablefmt='grid'))
# Out:
# Basic statistics for both numeric :
# +-------------------+---------+-------------+-------------+-------+--------+--------+---------+-------+
# |                   |   count |        mean |         std |   min |    25% |    50% |     75% |   max |
# +===================+=========+=============+=============+=======+========+========+=========+=======+
# | ApplicantIncome   |     614 | 5403.46     | 6109.04     |   150 | 2877.5 | 3812.5 | 5795    | 81000 |
# +-------------------+---------+-------------+-------------+-------+--------+--------+---------+-------+
# | CoapplicantIncome |     614 | 1621.25     | 2926.25     |     0 |    0   | 1188.5 | 2297.25 | 41667 |
# +-------------------+---------+-------------+-------------+-------+--------+--------+---------+-------+
# | LoanAmount        |     592 |  146.412    |   85.5873   |     9 |  100   |  128   |  168    |   700 |
# +-------------------+---------+-------------+-------------+-------+--------+--------+---------+-------+
# ...

# %%
# List of numerical columns
num_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# Plot histograms and boxplots for each
for col in num_cols:
    plt.figure(figsize=(12, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(loan[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}', fontsize=13)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(axis='y', linestyle='--', alpha=0.5)

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=loan[col], color='orange')
    plt.title(f'Boxplot of {col}', fontsize=13)
    plt.xlabel(col)
    plt.grid(axis='x', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# | **Column**           | **Skewed?** | **Outliers?** | **Missing?** | **Action**                                  |
# |----------------------|-------------|----------------|---------------|----------------------------------------------|
# | ApplicantIncome      | Yes         | Yes            | No            | Consider Square Root Transformation                  |
# | CoapplicantIncome    | Yes         | Yes            | No            | Consider lSquare Root Transformation                 |
# | LoanAmount           | Yes         | Yes            | Yes           | Fill missing with mean       |
# | Loan_Amount_Term     | No          | Few            | Yes           | Fill missing with mode (360)                 |
# | Credit_History       | No          | No             | Yes           | Fill missing with mode (1.0)                 |

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">4. | Data Preprocessing</p>

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.1 |</span><span style='color:#ff6200'> Drop Unecessary Variables</span></b>

# %%
# Drop identifier column
loan.drop("Loan_ID", axis=1, inplace=True)

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.2 |</span><span style='color:#ff6200'> Handling Missing Values</span></b>

# %%
plt.figure(figsize = (24, 5))
axz = plt.subplot(1,2,2)
mso.bar(loan, ax = axz, fontsize = 12);

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 4.2.1 Categorical features:</font></h2>

# %%
# Fill missing values for categorical features
loan['Gender'].fillna(loan['Gender'].mode()[0], inplace=True)
loan['Married'].fillna(loan['Married'].mode()[0], inplace=True)
loan['Dependents'].fillna(loan['Dependents'].mode()[0], inplace=True)
loan['Self_Employed'].fillna(loan['Self_Employed'].mode()[0], inplace=True)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> 4.2.2 Numeric features:</font></h2>

# %%
# Fill missing values for numeric features
loan['LoanAmount'].fillna(loan['LoanAmount'].mean(), inplace=True)
loan['Loan_Amount_Term'].fillna(loan['Loan_Amount_Term'].mode()[0], inplace=True)
loan['Credit_History'].fillna(loan['Credit_History'].mode()[0], inplace=True)

# %%
# 1. Total Income
loan['Total_Income'] = loan['ApplicantIncome'] + loan['CoapplicantIncome']

# 2. EMI (Estimated Monthly Installment)
loan['EMI'] = loan['LoanAmount'] / loan['Loan_Amount_Term']

# 3. Loan to Income Ratio
loan['Loan_Income_Ratio'] = loan['LoanAmount'] / loan['Total_Income']

# 4. Balance Income: Income left after paying EMI
loan['Balance_Income'] = loan['Total_Income'] - loan['EMI']

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.3 |</span><span style='color:#ff6200'> Encoding Categorical Variables</span></b>

# %%
loan = pd.get_dummies(loan)

# Drop columns
loan = loan.drop(['Gender_Female', 'Married_No', 'Education_Not Graduate', 
              'Self_Employed_No', 'Loan_Status_N'], axis = 1)

# Rename columns name
new = {'Gender_Male': 'Gender', 'Married_Yes': 'Married', 
       'Education_Graduate': 'Education', 'Self_Employed_Yes': 'Self_Employed',
       'Loan_Status_Y': 'Loan_Status'}
       
loan.rename(columns=new, inplace=True)

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.4 |</span><span style='color:#ff6200'>  Remove Outliers</span></b>

# %%
# Select only numeric columns for quantile calculation
numeric_loan = loan.select_dtypes(include=['number'])

# Calculate Q1, Q3, and IQR
Q1 = numeric_loan.quantile(0.25)
Q3 = numeric_loan.quantile(0.75)
IQR = Q3 - Q1

# Filter the original loan DataFrame using numeric column outlier conditions
loan = loan[~((numeric_loan < (Q1 - 1.5 * IQR)) | (numeric_loan > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.5 |</span><span style='color:#ff6200'>  Square Root Transformation to Fix Skewness</span></b>

# %%
# Apply Square Root Transformation to reduce skewness
loan.ApplicantIncome = np.sqrt(loan.ApplicantIncome)
loan.CoapplicantIncome = np.sqrt(loan.CoapplicantIncome)
loan.LoanAmount = np.sqrt(loan.LoanAmount)

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot 1: Applicant Income
sns.histplot(data=loan, x="ApplicantIncome", kde=True, ax=axs[0, 0], color='green')
axs[0, 0].set_title("Distribution of Applicant Income", fontsize=12)
axs[0, 0].set_xlabel("Applicant Income")
axs[0, 0].set_ylabel("Frequency")

# Plot 2: Coapplicant Income
sns.histplot(data=loan, x="CoapplicantIncome", kde=True, ax=axs[0, 1], color='skyblue')
axs[0, 1].set_title("Distribution of Coapplicant Income", fontsize=12)
axs[0, 1].set_xlabel("Coapplicant Income")
axs[0, 1].set_ylabel("Frequency")

# Plot 3: Loan Amount
sns.histplot(data=loan, x="LoanAmount", kde=True, ax=axs[1, 0], color='orange')
axs[1, 0].set_title("Distribution of Loan Amount", fontsize=12)
axs[1, 0].set_xlabel("Loan Amount")
axs[1, 0].set_ylabel("Frequency")

# Plot 4: Loan Status Count
sns.countplot(data=loan, x="Loan_Status", palette="Set2", ax=axs[1, 1])
axs[1, 1].set_title("Loan Status Distribution", fontsize=12)
axs[1, 1].set_xlabel("Loan Status")
axs[1, 1].set_ylabel("Count")

# Set main title
fig.suptitle("Loan Application Data Distributions", fontsize=16, fontweight='bold')

# Adjust layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.6 |</span><span style='color:#ff6200'> Feature-Target Split</span></b>

# %%
# Target column
y = loan['Loan_Status']

# Drop target and create feature set
X = loan.drop('Loan_Status', axis=1)

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.7 |</span><span style='color:#ff6200'> SMOTE Technique</span></b>

# %%
X, y = SMOTE().fit_resample(X, y)

# %%
sns.set_theme(style="darkgrid")
sns.countplot(y=y, data=loan, palette="coolwarm")
plt.ylabel('Loan Status')
plt.xlabel('Total')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * The number between approved and rejected loan is imbalanced. In this section, oversampling technique will be used to avoid overfitting.
#
# * After the this oversampling technique the distrubtion of Loan status are now balanced.

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.8 |</span><span style='color:#ff6200'> Data Normalization</span></b>

# %%
X = MinMaxScaler().fit_transform(X)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Data normalization will be performed to normalize the range of independent variables or features of data.

# %% [markdown]
# # <b><span style='color:#fcc36d'>4.9 |</span><span style='color:#ff6200'> Splitting Data Set</span></b>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print("Training Samples:", X_train.shape[0])
print("Testing Samples:", X_test.shape[0])
# Out:
# Training Samples: 505
# Testing Samples: 127

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - The data set will be split into **80% training dataset  and 20% testing dataset**.

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">5. | Machine Learning Models</p>

# %%
feature_names = loan.drop('Loan_Status', axis=1).columns.tolist()
feature_names
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Total_Income',
#  'EMI',
#  'Loan_Income_Ratio',
#  'Balance_Income',
#  'Gender',
#  'Married',
#  'Dependents_0',
#  'Dependents_1',
#  'Dependents_2',
#  'Dependents_3+',
#  'Education',
#  'Self_Employed',
#  'Property_Area_Rural',
#  'Property_Area_Semiurban',
#  'Property_Area_Urban']

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.1 |</span><span style='color:#ff6200'>  Logistic Regression</span></b>

# %%
lr_model = LogisticRegression(solver='saga', max_iter=5000, random_state=1)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000, random_state=1, solver='saga')

# %%
lr_pred = lr_model.predict(X_test)

# %%
lr_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': abs(lr_model.coef_[0])
}).sort_values(by='Importance', ascending=False)

# %%
# Plot top 20 features for Logistic Regression
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=lr_importance.head(20), palette='viridis')
plt.title(' Top 20 Important Features - Logistic Regression')
plt.xlabel('Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.2 |</span><span style='color:#ff6200'>  Decision Tree</span></b>

# %%
scoreListDT = []
for i in range(2,21):
    DT_model = DecisionTreeClassifier(max_leaf_nodes=i)
    DT_model.fit(X_train, y_train)
    scoreListDT.append(DT_model.score(X_test, y_test))

# %%
dt_pred = DT_model.predict(X_test)

# %%
plt.plot(range(2,21), scoreListDT)
plt.xticks(np.arange(2,21,1))
plt.xlabel("Leaf")
plt.ylabel("Score")
plt.show()
DTAcc = max(scoreListDT)
print("Decision Tree Accuracy: {:.2f}%".format(DTAcc*100))
# Out:
# Decision Tree Accuracy: 81.89%

# %%
dt_importances = DT_model.feature_importances_

dt_feat_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': dt_importances
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=dt_feat_df, x='Importance', y='Feature', palette='coolwarm')
plt.title("Decision Tree Feature Importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.3 |</span><span style='color:#ff6200'> Random Forest</span></b>

# %%
scoreListRF = []
for i in range(2,25):
    rf_model = RandomForestClassifier(n_estimators = 1000, random_state = 1, max_leaf_nodes=i)
    rf_model.fit(X_train, y_train)
    scoreListRF.append(rf_model.score(X_test, y_test))

# %%
rf_pred = rf_model.predict(X_test)

# %%
plt.plot(range(2,25), scoreListRF)
plt.xticks(np.arange(2,25,1))
plt.xlabel("RF Value")
plt.ylabel("Score")
plt.show()
RFAcc = max(scoreListRF)
print("Random Forest Accuracy:  {:.2f}%".format(RFAcc*100))
# Out:
# Random Forest Accuracy:  83.46%

# %%
rf_importances = rf_model.feature_importances_

rf_feat_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': rf_importances
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=rf_feat_df, x='Importance', y='Feature', palette='viridis')
plt.title("Random Forest Feature Importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.4 |</span><span style='color:#ff6200'>  Support Vector Machine (SVM)</span></b>

# %%
svm_model = SVC(kernel='linear', max_iter=5000)
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', max_iter=5000)

# %%
svm_pred = svm_model.predict(X_test)

# %%
svm_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': abs(svm_model.coef_[0])
}).sort_values(by='Importance', ascending=False)

# %%
# Plot top 20 features for SVM
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=svm_importance.head(10), palette='coolwarm')
plt.title('Top 10 Important Features - Support Vector Machine (SVM)')
plt.xlabel('Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.5 |</span><span style='color:#ff6200'> K-Nearest Neighbour (KNN)</span></b>

# %%
scoreListknn = []
for i in range(1,21):
    knn_model= KNeighborsClassifier(n_neighbors = i)
    knn_model.fit(X_train, y_train)
    scoreListknn.append(knn_model.score(X_test, y_test))

# %%
knn_pred = knn_model.predict(X_test)

# %%
plt.plot(range(1,21), scoreListknn)
plt.xticks(np.arange(1,21,1))
plt.xlabel("K value")
plt.ylabel("Score")
plt.show()
KNAcc = max(scoreListknn)
print("KNN best accuracy: {:.2f}%".format(KNAcc*100))
# Out:
# KNN best accuracy: 83.46%

# %%
knn_result = permutation_importance(knn_model, X_test, y_test, n_repeats=10, random_state=1)

knn_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': knn_result.importances_mean
}).sort_values(by='Importance', ascending=False)

# %%
# Plot top 20 important features for KNN using permutation importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=knn_importance.head(20), palette='viridis')
plt.title('Top 20 Important Features - KNN (Permutation Importance)')
plt.xlabel('Mean Importance (Permutation)')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>5.6 |</span><span style='color:#ff6200'> Model Comparison</span></b>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pandas as pd

models = {
    'Logistic Regression': lr_model,
    'Decision Tree': DT_model,
    'Random Forest': rf_model,
    'SVM': svm_model,
    'KNN': knn_model
}

model_results = {}


for model_name, model in models.items():
    y_pred = model.predict(X_test)  # Get predictions for the test set
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    
    if hasattr(model, "predict_proba"):
        probas_ = model.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, probas_)
    else:
        roc_auc = "Not Available"  
    
    
    model_results[model_name] = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1,
        'ROC-AUC': roc_auc
    }

comparison_table = pd.DataFrame(model_results).T
comparison_table = comparison_table.sort_values(by='Accuracy', ascending=False)
print(comparison_table)
# Out:
#                      Accuracy Precision    Recall  F1-Score        ROC-AUC
# Random Forest        0.826772  0.822581  0.822581  0.822581       0.931017
# Decision Tree         0.80315  0.768116  0.854839   0.80916       0.864268
# SVM                  0.795276  0.704545       1.0  0.826667  Not Available
# KNN                  0.795276  0.719512  0.951613  0.819444       0.894169
# Logistic Regression  0.779528    0.7125  0.919355  0.802817       0.901737

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * All models can achieve up to 70% accuracy.
# * Random Forest is the best model overall, balancing accuracy, precision, recall, F1-score, and ROC-AUC.
# * SVM might be suitable if the focus is on recall, but it’s less reliable in precision and lacks ROC-AUC information.
# * Decision Tree and KNN offer a good trade-off between recall and precision, but Random Forest remains superior.
# * Logistic Regression is the least performing in comparison, particularly in recall.

# %% [markdown]
# # <p style="background-color: #ff6200; font-family:calibri; color:white; font-size:140%; font-family:Verdana; text-align:center; border-radius:15px 50px;">6. | Model Selection</p>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# <h2 align="left"><font color=#ff6200> Based on the criteria above, Random Forest emerges as the best model. Here's why:</font></h2>
#
# - Overall Accuracy: It has the highest accuracy (88.98%).
# - Balance Between Precision and Recall: It provides a strong balance between precision and recall (0.8871 each), making it robust in both minimizing false positives and correctly identifying positive cases.
# - Feature Importance Interpretability: Random Forest offers clear and reliable feature importance metrics, helping us understand which features are driving the model's predictions.
# - Time & Resources Required: While it requires more resources than simpler models, its performance benefits outweigh the computational cost, especially when the accuracy and balance of metrics are prioritized.

# %% [markdown]
# # <b><span style='color:#fcc36d'>6.1 |</span><span style='color:#ff6200'> Random Forest Hyperparameter Tuning </span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# **Improve the random forest model’s performance further by fine-tuning the hyperparameters.**

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}
rf_grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=1), param_grid=param_grid, cv=5)
rf_grid_search.fit(X_train, y_train)
best_model = rf_grid_search.best_estimator_
print("Best parameters found: ", rf_grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %% [markdown]
# # <b><span style='color:#fcc36d'>6.2 |</span><span style='color:#ff6200'> Cross-Validation</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
#
# **Ensure  random forest model is generalizing well to unseen data.**

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(best_model, X_train, y_train, cv=5)
print(f"Cross-validated accuracy: {cv_scores.mean():.4f}")
# Out:
# Cross-validated accuracy: 0.8851

# %% [markdown]
# # <b><span style='color:#fcc36d'>6.3 |</span><span style='color:#ff6200'> Test Evaluation Metrics</span></b>

# %%
y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print(f"ROC-AUC: {roc_auc_score(y_test, y_proba):.4f}")
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      0.86      0.87        65
#         True       0.86      0.87      0.86        62
#
#     accuracy                           0.87       127
#    macro avg       0.87      0.87      0.87       127
# weighted avg       0.87      0.87      0.87       127
#
# ROC-AUC: 0.9392

# %% [markdown]
# # <b><span style='color:#fcc36d'>6.4 |</span><span style='color:#ff6200'> Feature Importance</span></b>

# %%
importances = best_model.feature_importances_
feature_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_df.sort_values(by='Importance', ascending=False, inplace=True)

plt.figure(figsize=(10, 6))
sns.barplot(data=feature_df.head(20), x='Importance', y='Feature')
plt.title('Top 20 Feature Importances')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><span style='color:#fcc36d'>6.5 |</span><span style='color:#ff6200'>  Save the model (Deployment Preparation)</span></b>

# %%
# Fix 1: Save the correct best model from GridSearchCV
joblib.dump(best_model, 'best_loan_model.joblib')
print("✅ Tuned Random Forest model saved successfully!")
# Out:
# ✅ Tuned Random Forest model saved successfully!

# %%
# Load model and make prediction
loaded_model = joblib.load('best_loan_model.joblib')
sample_prediction = loaded_model.predict(X_test[:1])
probas = loaded_model.predict_proba(X_test[:1])[0]

# Get correct class index
predicted_class = sample_prediction[0]
class_index = int(predicted_class)  # Convert bool to 0/1

# SHAP explanation
explainer = shap.TreeExplainer(loaded_model)
shap_values = explainer.shap_values(pd.DataFrame(X_test[:1], columns=feature_names))

# Display results
print(f"""
🔮 Loan Prediction Result:
-------------------------
Status Prediction: {'Approved (Y)' if predicted_class else 'Rejected (N)'}
Confidence Level: {probas[class_index]*100:.1f}%
""")
# Out:
# 🔮 Loan Prediction Result:
# -------------------------
# Status Prediction: Rejected (N)
# Confidence Level: 52.7%
